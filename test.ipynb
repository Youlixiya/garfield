# %%
import alpha_clip
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import alpha_clip
#
# File /data/wzj/garfield/AlphaCLIP/alpha_clip/__init__.py:1
# ----> 1 from .alpha_clip import *
#
# File /data/wzj/garfield/AlphaCLIP/alpha_clip/alpha_clip.py:13
#      10 from torchvision.transforms import Compose, Resize, CenterCrop, ToTensor, Normalize
#      11 from tqdm import tqdm
# ---> 13 from .model import build_model
#      14 from .simple_tokenizer import SimpleTokenizer as _Tokenizer
#      16 try:
#
# File /data/wzj/garfield/AlphaCLIP/alpha_clip/model.py:8
#       6 import torch.nn.functional as F
#       7 from torch import nn
# ----> 8 import loralib as lora
#       9 import math
#      10 import collections
#
# ModuleNotFoundError: No module named 'loralib'

# %%
import open_clip
model, _, _ = open_clip.create_model_and_transforms(
            "ViT-B-16",  # e.g., ViT-B-16
            pretrained="laion2b_s34b_b88k",  # e.g., laion2b_s34b_b88k
            precision="fp16",
        )
# Out:
# ---------------------------------------------------------------------------
# OfflineModeIsEnabled                      Traceback (most recent call last)
# File ~/data/anaconda3/envs/garfield_wzj/lib/python3.9/site-packages/huggingface_hub/file_download.py:1238, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout, endpoint)
#    1237 try:
# -> 1238     metadata = get_hf_file_metadata(
#    1239         url=url,
#    1240         token=token,
#    1241         proxies=proxies,
#    1242         timeout=etag_timeout,
#    1243         library_name=library_name,
#    1244         library_version=library_version,
#    1245         user_agent=user_agent,
#    1246     )
#    1247 except EntryNotFoundError as http_error:
#    1248     # Cache the non-existence of the file and raise
#
# File ~/data/anaconda3/envs/garfield_wzj/lib/python3.9/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/data/anaconda3/envs/garfield_wzj/lib/python3.9/site-packages/huggingface_hub/file_download.py:1631, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent)
#    1630 # Retrieve metadata
# -> 1631 r = _request_wrapper(
#    1632     method="HEAD",
#    1633     url=url,
#    1634     headers=headers,
#    1635     allow_redirects=False,
#    1636     follow_relative_redirects=True,
#    1637     proxies=proxies,
#    1638     timeout=timeout,
#    1639 )
#    1640 hf_raise_for_status(r)
#
# File ~/data/anaconda3/envs/garfield_wzj/lib/python3.9/site-packages/huggingface_hub/file_download.py:385, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     384 if follow_relative_redirects:
# --> 385     response = _request_wrapper(
#     386         method=method,
#     387         url=url,
#     388         follow_relative_redirects=False,
#     389         **params,
#     390     )
#     392     # If redirection, we redirect only relative paths.
#     393     # This is useful in case of a renamed repository.
#
# File ~/data/anaconda3/envs/garfield_wzj/lib/python3.9/site-packages/huggingface_hub/file_download.py:408, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     407 # Perform request and return if status_code is not in the retry list.
# --> 408 response = get_session().request(method=method, url=url, **params)
#     409 hf_raise_for_status(response)
#
# File ~/data/anaconda3/envs/garfield_wzj/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/data/anaconda3/envs/garfield_wzj/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/data/anaconda3/envs/garfield_wzj/lib/python3.9/site-packages/huggingface_hub/utils/_http.py:78, in OfflineAdapter.send(self, request, *args, **kwargs)
#      77 def send(self, request: PreparedRequest, *args, **kwargs) -> Response:
# ---> 78     raise OfflineModeIsEnabled(
#      79         f"Cannot reach {request.url}: offline mode is enabled. To disable it, please unset the `HF_HUB_OFFLINE` environment variable."
#      80     )
#
# OfflineModeIsEnabled: Cannot reach https://huggingface.co/laion/CLIP-ViT-B-16-laion2B-s34B-b88K/resolve/main/open_clip_pytorch_model.bin: offline mode is enabled. To disable it, please unset the `HF_HUB_OFFLINE` environment variable.
#
# The above exception was the direct cause of the following exception:
#
# LocalEntryNotFoundError                   Traceback (most recent call last)
# Cell In[1], line 2
#       1 import open_clip
# ----> 2 model, _, _ = open_clip.create_model_and_transforms(
#       3             "ViT-B-16",  # e.g., ViT-B-16
#       4             pretrained="laion2b_s34b_b88k",  # e.g., laion2b_s34b_b88k
#       5             precision="fp16",
#       6         )
#
# File ~/data/anaconda3/envs/garfield_wzj/lib/python3.9/site-packages/open_clip/factory.py:384, in create_model_and_transforms(model_name, pretrained, precision, device, jit, force_quick_gelu, force_custom_text, force_patch_dropout, force_image_size, image_mean, image_std, image_interpolation, image_resize_mode, aug_cfg, pretrained_image, pretrained_hf, cache_dir, output_dict, **model_kwargs)
#     360 def create_model_and_transforms(
#     361         model_name: str,
#     362         pretrained: Optional[str] = None,
#    (...)
#     379         **model_kwargs,
#     380 ):
#     381     force_preprocess_cfg = merge_preprocess_kwargs(
#     382         {}, mean=image_mean, std=image_std, interpolation=image_interpolation, resize_mode=image_resize_mode)
# --> 384     model = create_model(
#     385         model_name,
#     386         pretrained,
#     387         precision=precision,
#     388         device=device,
#     389         jit=jit,
#     390         force_quick_gelu=force_quick_gelu,
#     391         force_custom_text=force_custom_text,
#     392         force_patch_dropout=force_patch_dropout,
#     393         force_image_size=force_image_size,
#     394         force_preprocess_cfg=force_preprocess_cfg,
#     395         pretrained_image=pretrained_image,
#     396         pretrained_hf=pretrained_hf,
#     397         cache_dir=cache_dir,
#     398         output_dict=output_dict,
#     399         **model_kwargs,
#     400     )
#     402     pp_cfg = PreprocessCfg(**model.visual.preprocess_cfg)
#     404     preprocess_train = image_transform_v2(
#     405         pp_cfg,
#     406         is_train=True,
#     407         aug_cfg=aug_cfg,
#     408     )
#
# File ~/data/anaconda3/envs/garfield_wzj/lib/python3.9/site-packages/open_clip/factory.py:283, in create_model(model_name, pretrained, precision, device, jit, force_quick_gelu, force_custom_text, force_patch_dropout, force_image_size, force_preprocess_cfg, pretrained_image, pretrained_hf, cache_dir, output_dict, require_pretrained, **model_kwargs)
#     281 pretrained_cfg = get_pretrained_cfg(model_name, pretrained)
#     282 if pretrained_cfg:
# --> 283     checkpoint_path = download_pretrained(pretrained_cfg, cache_dir=cache_dir)
#     284     preprocess_cfg = merge_preprocess_dict(preprocess_cfg, pretrained_cfg)
#     285 elif os.path.exists(pretrained):
#
# File ~/data/anaconda3/envs/garfield_wzj/lib/python3.9/site-packages/open_clip/pretrained.py:582, in download_pretrained(cfg, force_hf_hub, cache_dir)
#     580         target = download_pretrained_from_hf(model_id, filename=filename, cache_dir=cache_dir)
#     581     else:
# --> 582         target = download_pretrained_from_hf(model_id, cache_dir=cache_dir)
#     584 return target
#
# File ~/data/anaconda3/envs/garfield_wzj/lib/python3.9/site-packages/open_clip/pretrained.py:552, in download_pretrained_from_hf(model_id, filename, revision, cache_dir)
#     545 def download_pretrained_from_hf(
#     546         model_id: str,
#     547         filename: str = 'open_clip_pytorch_model.bin',
#     548         revision=None,
#     549         cache_dir: Union[str, None] = None,
#     550 ):
#     551     has_hf_hub(True)
# --> 552     cached_file = hf_hub_download(model_id, filename, revision=revision, cache_dir=cache_dir)
#     553     return cached_file
#
# File ~/data/anaconda3/envs/garfield_wzj/lib/python3.9/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/data/anaconda3/envs/garfield_wzj/lib/python3.9/site-packages/huggingface_hub/file_download.py:1371, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout, endpoint)
#    1368         raise head_call_error
#    1369     else:
#    1370         # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
# -> 1371         raise LocalEntryNotFoundError(
#    1372             "An error happened while trying to locate the file on the Hub and we cannot find the requested files"
#    1373             " in the local cache. Please check your connection and try again or make sure your Internet connection"
#    1374             " is on."
#    1375         ) from head_call_error
#    1377 # From now on, etag and commit_hash are not None.
#    1378 assert etag is not None, "etag must have been retrieved from server"
#
# LocalEntryNotFoundError: An error happened while trying to locate the file on the Hub and we cannot find the requested files in the local cache. Please check your connection and try again or make sure your Internet connection is on.
